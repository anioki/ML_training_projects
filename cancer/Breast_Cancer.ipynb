# %% [markdown]
# <a href="https://colab.research.google.com/github/anioki/ML_training_projects/blob/main/cancer/Breast_Cancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import log_loss, accuracy_score
import xgboost as xgb

# %% [markdown]
# #Download data

# %%
! pip install -q kaggle

# %%
from google.colab import files
files.upload()

# %%
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
! kaggle datasets list
# Out:
# ...
# ref                                                           title                                              size  lastUpdated          downloadCount
# ------------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------
# gpreda/reddit-vaccine-myths                                   Reddit Vaccine Myths                              232KB  2021-06-28 07:58:31           8446
# crowww/a-large-scale-fish-dataset                             A Large Scale Fish Dataset                          3GB  2021-04-28 17:03:01           5167
# imsparsh/musicnet-dataset                                     MusicNet Dataset                                   22GB  2021-02-18 14:12:19           1775
# promptcloud/careerbuilder-job-listing-2020                    Careerbuilder Job Listing 2020                     42MB  2021-03-05 06:59:52           1186
# ...

# %%
! kaggle datasets download -d uciml/breast-cancer-wisconsin-data
# Out:
# ...
#   0% 0.00/48.6k [00:00<?, ?B/s]
# 100% 48.6k/48.6k [00:00<00:00, 18.6MB/s]

# %%
! mkdir data
! unzip breast-cancer-wisconsin-data.zip -d data
# Out:
# Archive:  breast-cancer-wisconsin-data.zip
#   inflating: data/data.csv

# %%
df = pd.read_csv('/content/data/data.csv', encoding="ISO-8859-1")
df
# Out:
#            id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0      842302         M  ...                  0.11890          NaN
# 1      842517         M  ...                  0.08902          NaN
# 2    84300903         M  ...                  0.08758          NaN
# 3    84348301         M  ...                  0.17300          NaN
# 4    84358402         M  ...                  0.07678          NaN
# ..        ...       ...  ...                      ...          ...
# 564    926424         M  ...                  0.07115          NaN
# 565    926682         M  ...                  0.06637          NaN
# 566    926954         M  ...                  0.07820          NaN
# 567    927241         M  ...                  0.12400          NaN
# 568     92751         B  ...                  0.07039          NaN
#
# [569 rows x 33 columns]

# %% [markdown]
# #Data Observation and Preprocessing

# %%
df.drop(['id', 'Unnamed: 32'], axis=1, inplace=True)

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
df.isnull().any()
# Out:
# diagnosis                  False
# radius_mean                False
# texture_mean               False
# perimeter_mean             False
# area_mean                  False
# smoothness_mean            False
# compactness_mean           False
# concavity_mean             False
# concave points_mean        False
# symmetry_mean              False
# fractal_dimension_mean     False
# radius_se                  False
# texture_se                 False
# perimeter_se               False
# area_se                    False
# smoothness_se              False
# compactness_se             False
# concavity_se               False
# concave points_se          False
# symmetry_se                False
# fractal_dimension_se       False
# radius_worst               False
# texture_worst              False
# perimeter_worst            False
# area_worst                 False
# smoothness_worst           False
# compactness_worst          False
# concavity_worst            False
# ...

# %%
pd.Series(df['diagnosis']).unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
ax = sns.countplot(x='diagnosis', data=df)
plt.xticks()
# Out:
# (array([0, 1]), <a list of 2 Text major ticklabel objects>)

# %%
df_group=df.groupby(by=['diagnosis'])
df_group.mean()
# Out:
#            radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# diagnosis                             ...
# B            12.146524     17.914762  ...        0.270246                 0.079442
# M            17.462830     21.604906  ...        0.323468                 0.091530
#
# [2 rows x 30 columns]

# %%
df['diagnosis'] = df['diagnosis'].replace(['M'], 0)
df['diagnosis'] = df['diagnosis'].replace(['B'], 1)

# %%
df.describe()
# Out:
#         diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# count  569.000000   569.000000  ...      569.000000               569.000000
# mean     0.627417    14.127292  ...        0.290076                 0.083946
# std      0.483918     3.524049  ...        0.061867                 0.018061
# min      0.000000     6.981000  ...        0.156500                 0.055040
# 25%      0.000000    11.700000  ...        0.250400                 0.071460
# 50%      1.000000    13.370000  ...        0.282200                 0.080040
# 75%      1.000000    15.780000  ...        0.317900                 0.092080
# max      1.000000    28.110000  ...        0.663800                 0.207500
#
# [8 rows x 31 columns]

# %%
f, ax = plt.subplots(figsize=(16, 12))
sns.heatmap(df.corr(), annot=True,linewidths=0.25,vmax=1.0,)
plt.show()

# %%
name = df.columns
name
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
df1 = df
y = df['diagnosis']
df1.drop('diagnosis', axis=1, inplace=True)
x = df1.values 
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df1 = pd.DataFrame(x_scaled)
df1.columns = name[1:]

# %%
df1
# Out:
#      radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# 0       0.521037      0.022658  ...        0.598462                 0.418864
# 1       0.643144      0.272574  ...        0.233590                 0.222878
# 2       0.601496      0.390260  ...        0.403706                 0.213433
# 3       0.210090      0.360839  ...        1.000000                 0.773711
# 4       0.629893      0.156578  ...        0.157500                 0.142595
# ..           ...           ...  ...             ...                      ...
# 564     0.690000      0.428813  ...        0.097575                 0.105667
# 565     0.622320      0.626987  ...        0.198502                 0.074315
# 566     0.455251      0.621238  ...        0.128721                 0.151909
# 567     0.644564      0.663510  ...        0.497142                 0.452315
# 568     0.036869      0.501522  ...        0.257441                 0.100682
#
# [569 rows x 30 columns]

# %%
df1[name[0]] = y
df1
# Out:
#      radius_mean  texture_mean  ...  fractal_dimension_worst  diagnosis
# 0       0.521037      0.022658  ...                 0.418864          0
# 1       0.643144      0.272574  ...                 0.222878          0
# 2       0.601496      0.390260  ...                 0.213433          0
# 3       0.210090      0.360839  ...                 0.773711          0
# 4       0.629893      0.156578  ...                 0.142595          0
# ..           ...           ...  ...                      ...        ...
# 564     0.690000      0.428813  ...                 0.105667          0
# 565     0.622320      0.626987  ...                 0.074315          0
# 566     0.455251      0.621238  ...                 0.151909          0
# 567     0.644564      0.663510  ...                 0.452315          0
# 568     0.036869      0.501522  ...                 0.100682          1
#
# [569 rows x 31 columns]

# %%
from sklearn.model_selection import train_test_split
train_data, test_data = train_test_split(df1, train_size =0.8, random_state = 3)
train_data
# Out:
#      radius_mean  texture_mean  ...  fractal_dimension_worst  diagnosis
# 280     0.576412      0.571187  ...                 0.276532          0
# 186     0.536182      0.299966  ...                 0.094057          0
# 437     0.334091      0.212039  ...                 0.113472          1
# 329     0.439159      0.411566  ...                 0.160632          0
# 201     0.499740      0.324992  ...                 0.154991          0
# ..           ...           ...  ...                      ...        ...
# 480     0.245113      0.281366  ...                 0.145940          1
# 422     0.219083      0.213392  ...                 0.126131          1
# 119     0.519144      0.348326  ...                 0.039814          0
# 256     0.594870      0.644572  ...                 0.298177          0
# 249     0.214823      0.176530  ...                 0.151187          1
#
# [455 rows x 31 columns]

# %%
name = list(name)
name.pop(0)
name
# Out:
# ['radius_mean',
#  'texture_mean',
#  'perimeter_mean',
#  'area_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'concave points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean',
#  'radius_se',
#  'texture_se',
#  'perimeter_se',
#  'area_se',
#  'smoothness_se',
#  'compactness_se',
#  'concavity_se',
#  'concave points_se',
#  'symmetry_se',
#  'fractal_dimension_se',
#  'radius_worst',
#  'texture_worst',
#  'perimeter_worst',
#  'area_worst',
#  'smoothness_worst',
#  'compactness_worst',
#  'concavity_worst',
#  'concave points_worst',
#  'symmetry_worst',
#  'fractal_dimension_worst']

# %%
train_data_x, train_data_y, test_data_x, test_data_y = train_data[name], train_data['diagnosis'], test_data[name], test_data['diagnosis']

# %%
train_data_x.shape, train_data_y.shape
# Out:
# ((455, 30), (455,))

# %% [markdown]
# #Model

# %%
DTC = DecisionTreeClassifier()
DTC.fit(train_data_x, train_data_y)
DTC_pred  = DTC.predict(test_data_x)
DTC_prob  = DTC.predict_proba(test_data_x)

DTC_accuracy = accuracy_score(test_data_y, DTC_pred)
DTC_logloss = log_loss(test_data_y, DTC_prob)

print("Accuracy: {0:.2f}".format(DTC_accuracy))
print("Log loss: {0:.2f}".format(DTC_logloss))
print("Number of nodes created: {}".format(DTC.tree_.node_count))
# Out:
# Accuracy: 0.89
# Log loss: 3.64
# Number of nodes created: 41

# %%
adaboost = AdaBoostClassifier(
    base_estimator=DecisionTreeClassifier(max_depth=1),
    algorithm='SAMME',
    n_estimators=10)

adaboost.fit(train_data_x, train_data_y)
adaboost_y_pred = adaboost.predict(test_data_x)
adaboost_y_pred_prob = adaboost.predict_proba(test_data_x)

adaboost_accuracy = accuracy_score(test_data_y, adaboost_y_pred)
adaboost_logloss = log_loss(test_data_y, adaboost_y_pred_prob)

print("Accuracy: {0:.2f}".format(adaboost_accuracy))
print("Log loss: {0:.2f}".format(adaboost_logloss))
# Out:
# Accuracy: 0.96
# Log loss: 0.47

# %%
clf = xgb.XGBClassifier(n_estimators = 200, 
                       learning_rate = 0.5,
                       max_depth=20,
                       n_jobs=5)
clf.fit(train_data_x, train_data_y, verbose=False)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.5, max_delta_step=0, max_depth=20,
#               min_child_weight=1, missing=None, n_estimators=200, n_jobs=5,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
preds_prob = clf.predict(test_data_x)

preds = preds_prob > 0.5 
preds1 = np.array(test_data_y == 1)
correct = 0

for i in range(len(preds)):
    if preds[i] == preds1[1]:
        correct += 1

print('Predicted correctly: {0}/{1}'.format(correct, len(preds)))
print('Error: {0:.4f}'.format(1-correct/len(preds)))
# Out:
# Predicted correctly: 76/114
# Error: 0.3333
