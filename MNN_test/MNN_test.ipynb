# %% [markdown]
# <a href="https://colab.research.google.com/github/anioki/ML_training_projects/blob/main/MNN_test/MNN_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Download data

# %%
import urllib.request
url = 'https://image1.thematicnews.com/uploads/topics/preview/00/03/08/69/9fe4198bfd_256crop.png'
img = urllib.request.urlopen(url).read()
out = open("dog.jpg", "wb")
out.write(img)

url = 'data:image/jpeg;base64,...'
img = urllib.request.urlopen(url).read()
out = open("cat.jpg", "wb")
out.write(img)

url = 'https://comments-images.rozetka.com.ua/goods_comments/0/0/3/403/3403726.256x256.jpg'
img = urllib.request.urlopen(url).read()
out = open("pen.jpg", "wb")
out.write(img)

url = 'data:image/jpeg;base64,...'
img = urllib.request.urlopen(url).read()
out = open("dog_paint.jpg", "wb")
out.write(img)

url = 'https://pbs.twimg.com/profile_images/591400671632498689/yNiaGVpq_400x400.jpg'
img = urllib.request.urlopen(url).read()
out = open("squirrel.jpg", "wb")
out.write(img)
out.close
# Out:
# <function BufferedWriter.close>

# %% [markdown]
# #Data Preprocessing

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

def prepare_image(file):
    img_path = '/content/'
    img = image.load_img(img_path + file, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array_expanded_dims = np.expand_dims(img_array, axis=0)
    return tf.keras.applications.mobilenet.preprocess_input(img_array_expanded_dims)

# %% [markdown]
# #Model

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications import imagenet_utils
mobile = tf.keras.applications.mobilenet.MobileNet()

# %% [markdown]
# #Predict

# %%
from IPython.display import Image
Image(filename='/content/cat.jpg')

# %%
preprocessed_image = prepare_image('cat.jpg')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# [[('n02124075', 'Egyptian_cat', 0.85459936),
#   ('n02123045', 'tabby', 0.1280481),
#   ('n02123159', 'tiger_cat', 0.013419486),
#   ('n02127052', 'lynx', 0.0003873374),
#   ('n07932039', 'eggnog', 0.00037436988)]]

# %%
Image(filename='/content/dog.jpg')

# %%
preprocessed_image = prepare_image('dog.jpg')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# [[('n02099601', 'golden_retriever', 0.7548796),
#   ('n04409515', 'tennis_ball', 0.065468244),
#   ('n02099712', 'Labrador_retriever', 0.04692635),
#   ('n02106662', 'German_shepherd', 0.024576172),
#   ('n02112137', 'chow', 0.01498731)]]

# %% [markdown]
# #Predict function

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def predict_img(file):
  img_path = '/content/'
  img = img_path + file
  img = mpimg.imread(img)
  plt.imshow(img)
  preprocessed_image = prepare_image(file)
  predictions = mobile.predict(preprocessed_image)
  results = imagenet_utils.decode_predictions(predictions)
  print(results[0][0][1], ', accuracy:', results[0][0][2]) 
  return results

# %%
predict_img('pen.jpg')
# Out:
# ballpoint , accuracy: 0.86060864
# [[('n02783161', 'ballpoint', 0.86060864),
#   ('n03250847', 'drumstick', 0.032271545),
#   ('n03658185', 'letter_opener', 0.024165938),
#   ('n03388183', 'fountain_pen', 0.024142602),
#   ('n03476684', 'hair_slide', 0.015673168)]]

# %%
predict_img('dog_paint.jpg')
# Out:
# Lakeland_terrier , accuracy: 0.3158605
# [[('n02095570', 'Lakeland_terrier', 0.3158605),
#   ('n01704323', 'triceratops', 0.28850737),
#   ('n02095314', 'wire-haired_fox_terrier', 0.087374754),
#   ('n02093859', 'Kerry_blue_terrier', 0.0837879),
#   ('n02100236', 'German_short-haired_pointer', 0.047423217)]]

# %%
r = predict_img('squirrel.jpg')
# Out:
# fox_squirrel , accuracy: 0.6286538

# %%
r
# Out:
# [[('n02356798', 'fox_squirrel', 0.6286538),
#   ('n02443114', 'polecat', 0.06804694),
#   ('n02326432', 'hare', 0.06046924),
#   ('n02442845', 'mink', 0.035294984),
#   ('n02342885', 'hamster', 0.027202597)]]
